# %% [markdown]
# <a href="https://colab.research.google.com/github/Nafiz-kodar/Machine_learning_project/blob/main/422_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Features Description
#
# Age → Age of the individual (years)
#
# Gender → Gender of the individual
#
# Height → Height of the individual (in meters)
#
# Weight → Weight of the individual (in kilograms)
#
# CALC → Consumption of Alcohol
#
# FAVC → Frequent consumption of High Caloric food
#
# FCVC → Frequency of Consumption of Vegetables
#
# NCP → Number of main meals (per day)
#
# SCC → Calories Consumption Monitoring
#
# SMOKE → Smoking habit
#
# CH2O → Consumption of Water (daily water intake)
#
# family_history_with_overweight → Family history with overweight/obesity
#
# FAF → Frequency of Physical Activity
#
# TUE → Time Using Technology devices
#
# CAEC → Consumption of food Between meals
#
# MTRANS → Mode of Transportation
#
# NObeyesdad → Nutritional Obesity Level (Obesity diagnosis)

# %% [markdown]
# ## **Data Cleaning**

# %% [markdown]
# **Libraries**

# %%
import pandas as pd

# %%
df =pd.read_csv('/content/Updated_Obesity_Dataset.csv')

# %%
df.shape
df.columns
# Out:
# Index(['Age', 'Gender', 'Height', 'Weight', 'CALC', 'FAVC', 'FCVC', 'NCP',
#        'SCC', 'SMOKE', 'CH2O', 'family_history_with_overweight', 'FAF', 'TUE',
#        'CAEC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
df.head()
# Out:
#     Age  Gender  Height  Weight        CALC FAVC  FCVC  NCP  SCC SMOKE  CH2O  \
# 0  21.0  Female    1.62    64.0          no   no   2.0  3.0   no    no   2.0
# 1  21.0  Female    1.52    56.0   Sometimes   no   3.0  3.0  yes   yes   3.0
# 2  23.0    Male    1.80    77.0  Frequently   no   2.0  3.0   no    no   2.0
# 3  27.0    Male    1.80    87.0  Frequently   no   3.0  3.0   no    no   2.0
# 4  22.0    Male    1.78    89.8   Sometimes   no   2.0  1.0   no    no   2.0
#
#   family_history_with_overweight  FAF  TUE       CAEC                 MTRANS  \
# 0                            yes  0.0  1.0  Sometimes  Public_Transportation
# 1                            yes  3.0  0.0  Sometimes  Public_Transportation
# 2                            yes  2.0  1.0  Sometimes  Public_Transportation
# 3                             no  2.0  0.0  Sometimes                Walking
# 4                             no  0.0  0.0  Sometimes  Public_Transportation
#
#             NObeyesdad
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             2111 non-null   float64
#  1   Gender                          2100 non-null   object
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   CALC                            2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   SCC                             2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2090 non-null   float64
#  11  family_history_with_overweight  2090 non-null   object
# ...

# %%
df['NObeyesdad'].value_counts()
# Out:
# NObeyesdad
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: count, dtype: int64

# %% [markdown]
# Null Vals

# %%
df.isnull().sum()
# Out:
# Age                                0
# Gender                            11
# Height                             0
# Weight                             0
# CALC                               0
# FAVC                               0
# FCVC                               0
# NCP                                0
# SCC                                0
# SMOKE                              0
# CH2O                              21
# family_history_with_overweight    21
# FAF                                0
# TUE                                0
# CAEC                               0
# MTRANS                             0
# NObeyesdad                         0
# dtype: int64

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-700870124.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)

# %%
df['CH2O'].fillna(df['CH2O'].median(), inplace=True)
# Out:
# /tmp/ipython-input-2400786316.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CH2O'].fillna(df['CH2O'].median(), inplace=True)

# %%
df['family_history_with_overweight'].fillna(df['family_history_with_overweight'].mode()[0],inplace=True)
# Out:
# /tmp/ipython-input-2629551306.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['family_history_with_overweight'].fillna(df['family_history_with_overweight'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                               0
# Gender                            0
# Height                            0
# Weight                            0
# CALC                              0
# FAVC                              0
# FCVC                              0
# NCP                               0
# SCC                               0
# SMOKE                             0
# CH2O                              0
# family_history_with_overweight    0
# FAF                               0
# TUE                               0
# CAEC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %% [markdown]
# Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(23)

# %%
duplicate_rows = df[df.duplicated(keep=False)]
duplicate_rows
# Out:
#       Age  Gender  Height  Weight       CALC FAVC  FCVC  NCP SCC SMOKE  CH2O  \
# 97   21.0  Female    1.52    42.0  Sometimes   no   3.0  1.0  no    no   1.0
# 98   21.0  Female    1.52    42.0  Sometimes   no   3.0  1.0  no    no   1.0
# 105  25.0  Female    1.57    55.0  Sometimes  yes   2.0  1.0  no    no   2.0
# 106  25.0  Female    1.57    55.0  Sometimes  yes   2.0  1.0  no    no   2.0
# 145  21.0    Male    1.62    70.0  Sometimes  yes   2.0  1.0  no    no   3.0
# 174  21.0    Male    1.62    70.0  Sometimes  yes   2.0  1.0  no    no   3.0
# 179  21.0    Male    1.62    70.0  Sometimes  yes   2.0  1.0  no    no   3.0
# 184  21.0    Male    1.62    70.0  Sometimes  yes   2.0  1.0  no    no   3.0
# 208  22.0  Female    1.69    65.0  Sometimes  yes   2.0  3.0  no    no   2.0
# 209  22.0  Female    1.69    65.0  Sometimes  yes   2.0  3.0  no    no   2.0
# 282  18.0  Female    1.62    55.0         no  yes   2.0  3.0  no    no   1.0
# ...

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Scaling & Encoding

# %%
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns
print(numerical_features)
# Out:
# Index(['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE'], dtype='object')

# %%
categorical_features = df.select_dtypes(include=['object']).columns
categorical_features
# Out:
# Index(['Gender', 'CALC', 'FAVC', 'SCC', 'SMOKE',
#        'family_history_with_overweight', 'CAEC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %% [markdown]
# Train-test splitting

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
x=df.drop('NObeyesdad',axis=1)
y=df['NObeyesdad']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=123)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1670, 16)
# (418, 16)
# (1670,)
# (418,)

# %%
categorical_features=x.select_dtypes(include=['object']).columns
numerical_features=x.select_dtypes(include=['int64', 'float64']).columns

# %%
scaler=StandardScaler()

x_train[numerical_features] = scaler.fit_transform(x_train[numerical_features])
x_test[numerical_features]= scaler.transform(x_test[numerical_features])

# %%
print('Head of x_train after scaling:')
display(x_train[numerical_features].head())
# Out:
# Head of x_train after scaling:
#            Age    Height    Weight      FCVC       NCP      CH2O       FAF  \
# 322  -0.209108  0.513896 -1.166528  1.073010  0.389266 -0.010500  1.175146
# 1167 -0.584893 -2.041286 -0.832202 -0.263396  0.667028 -0.010500  0.118220
# 1733  1.013584  0.874490  1.273563 -0.172655  0.389266  0.482033 -0.515581
# 457  -0.854503 -2.141203 -1.581936 -0.820096  0.389266 -1.652944 -1.181665
# 2083  0.028035 -0.406457  0.988957  1.073010  0.389266  1.027893 -0.827007
#
#            TUE
# 322  -1.084398
# 1167  0.985791
# 1733  0.429187
# 457  -1.084398
# 2083 -0.641875

# %%
print('\nMean of numerical features in x_train after scaling:')
display(x_train[numerical_features].mean())
print('\nStandard deviation of numerical features in x_train after scaling:')
display(x_train[numerical_features].std())
# Out:
# Mean of numerical features in x_train after scaling:
# Age      -1.957184e-16
# Height    1.378538e-15
# Weight    3.637809e-16
# FCVC      1.840178e-16
# NCP      -4.595127e-16
# CH2O     -3.403798e-17
# FAF       4.254747e-18
# TUE       8.509494e-18
# dtype: float64
# Standard deviation of numerical features in x_train after scaling:
# Age       1.0003
# Height    1.0003
# Weight    1.0003
# FCVC      1.0003
# NCP       1.0003
# CH2O      1.0003
# FAF       1.0003
# TUE       1.0003
# dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in categorical_features:
    x_train[col] = le.fit_transform(x_train[col])
    x_test[col] = le.transform(x_test[col])

# %%
print('x_train after all transformations:')
display(x_train.head())
print('\nx_test after all transformations:')
display(x_test.head())
# Out:
# x_train after all transformations:
#            Age  Gender    Height    Weight  CALC  FAVC      FCVC       NCP  \
# 322  -0.209108       0  0.513896 -1.166528     2     0  1.073010  0.389266
# 1167 -0.584893       0 -2.041286 -0.832202     3     0 -0.263396  0.667028
# 1733  1.013584       1  0.874490  1.273563     2     1 -0.172655  0.389266
# 457  -0.854503       0 -2.141203 -1.581936     2     1 -0.820096  0.389266
# 2083  0.028035       0 -0.406457  0.988957     2     1  1.073010  0.389266
#
#       SCC  SMOKE      CH2O  family_history_with_overweight       FAF  \
# 322     0      0 -0.010500                               0  1.175146
# 1167    0      0 -0.010500                               1  0.118220
# 1733    0      0  0.482033                               1 -0.515581
# 457     0      0 -1.652944                               0 -1.181665
# 2083    0      0  1.027893                               1 -0.827007
#
#            TUE  CAEC  MTRANS
# 322  -1.084398     1       3
# ...

# %% [markdown]
# # **NAIVE BAYES**

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
nb_y_pred = model.predict(x_test)
#print(y_pred)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Accuracy:", accuracy_score(y_test, nb_y_pred))
print(classification_report(y_test, nb_y_pred))
print(confusion_matrix(y_test, nb_y_pred))
# Out:
# Accuracy: 0.5598086124401914
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.46      0.95      0.62        55
#       Normal_Weight       0.50      0.09      0.16        53
#      Obesity_Type_I       0.43      0.74      0.55        81
#     Obesity_Type_II       0.68      0.84      0.75        58
#    Obesity_Type_III       0.98      0.98      0.98        58
#  Overweight_Level_I       0.36      0.07      0.11        60
# Overweight_Level_II       0.47      0.13      0.21        53
#
#            accuracy                           0.56       418
#           macro avg       0.56      0.54      0.48       418
#        weighted avg       0.55      0.56      0.49       418
#
# [[52  2  0  0  0  1  0]
#  [37  5  4  0  1  4  2]
#  [ 0  1 60 15  0  0  5]
#  [ 0  0  8 49  0  0  1]
#  [ 0  0  0  1 57  0  0]
#  [21  1 34  0  0  4  0]
#  [ 3  1 33  7  0  2  7]]

# %% [markdown]
# # **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=3)
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn_y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Accuracy:", accuracy_score(y_test, knn_y_pred))
print(classification_report(y_test, knn_y_pred))
print(confusion_matrix(y_test, knn_y_pred))
# Out:
# Accuracy: 0.8301435406698564
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       0.79      0.98      0.88        55
#       Normal_Weight       0.79      0.36      0.49        53
#      Obesity_Type_I       0.83      0.90      0.86        81
#     Obesity_Type_II       0.87      0.93      0.90        58
#    Obesity_Type_III       1.00      1.00      1.00        58
#  Overweight_Level_I       0.75      0.80      0.77        60
# Overweight_Level_II       0.76      0.77      0.77        53
#
#            accuracy                           0.83       418
#           macro avg       0.83      0.82      0.81       418
#        weighted avg       0.83      0.83      0.82       418
#
# [[54  1  0  0  0  0  0]
#  [11 19  2  2  0 12  7]
#  [ 1  0 73  1  0  1  5]
#  [ 0  0  3 54  0  1  0]
#  [ 0  0  0  0 58  0  0]
#  [ 2  2  5  2  0 48  1]
#  [ 0  2  5  3  0  2 41]]
